# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
past_load=pd.read_csv("raw/past_load/year_2022.csv")
weather=pd.read_csv("raw/weather/weatherdelhi.csv")
holiday=pd.read_csv("raw/holiday/holidays_2022.csv")

# %%
past_load.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7749 entries, 0 to 7748
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DELHI      7749 non-null   float64
#  1   BRPL       7749 non-null   float64
#  2   BYPL       7749 non-null   float64
#  3   NDPL       7749 non-null   float64
#  4   NDMC       7749 non-null   float64
#  5   MES        7749 non-null   float64
#  6   datetime   7749 non-null   object
#  7   day        7749 non-null   float64
#  8   month      7749 non-null   float64
#  9   year       7749 non-null   float64
#  10  dayofweek  7749 non-null   float64
# dtypes: float64(10), object(1)
# memory usage: 666.1+ KB

# %%
past_load.describe().T
# Out:
#             count         mean          std      min      25%      50%  \
# DELHI      7749.0  4037.130101  1282.116754  1318.11  3134.93  4004.24
# BRPL       7749.0  1687.540871   575.671339   480.36  1269.66  1656.57
# BYPL       7749.0   880.741990   297.890573   243.39   670.41   890.49
# NDPL       7749.0  1224.180181   352.659267   356.25  1003.60  1233.39
# NDMC       7749.0   178.551974    64.043861    13.89   132.88   166.81
# MES        7749.0    27.783582     8.372526     0.00    21.90    27.39
# day        7749.0    15.463157     8.790488     1.00     8.00    15.00
# month      7749.0     6.240289     3.239067     1.00     3.00     6.00
# year       7749.0  2022.000000     0.000000  2022.00  2022.00  2022.00
# dayofweek  7749.0     2.998064     2.006538     0.00     1.00     3.00
#
#                75%      max
# DELHI      4984.80  7654.00
# BRPL       2107.94  3347.81
# BYPL       1103.55  1733.75
# NDPL       1481.76  2207.68
# NDMC        210.26   395.21
# ...

# %%
past_load['datetime']=pd.to_datetime(past_load['datetime'])

# %%
past_load
# Out:
#         DELHI     BRPL    BYPL     NDPL    NDMC    MES            datetime  \
# 0     2144.41   860.87  428.55   691.40  117.82  25.93 2022-01-01 00:00:00
# 1     1839.04   727.39  349.29   609.45  111.57  23.50 2022-01-01 01:00:00
# 2     1682.70   669.86  316.20   573.91   84.25  22.44 2022-01-01 02:00:00
# 3     1578.43   627.90  290.02   539.32   79.86  21.11 2022-01-01 03:00:00
# 4     1584.39   644.04  289.28   542.23   71.18  22.41 2022-01-01 04:00:00
# ...       ...      ...     ...      ...     ...    ...                 ...
# 7744  2852.01  1199.39  573.20   904.03  120.03  28.24 2022-12-10 07:00:00
# 7745  3354.54  1402.00  709.99  1045.22  132.66  31.37 2022-12-10 08:00:00
# 7746  3445.52  1467.49  735.45  1033.79  146.23  29.66 2022-12-10 09:00:00
# 7747  3775.86  1633.29  773.82  1152.83  151.74  27.70 2022-12-10 10:00:00
# 7748  3725.10  1574.18  794.12  1146.95  149.58  25.05 2022-12-10 11:00:00
#
#        day  month    year  dayofweek
# ...

# %%
past_load.set_index('datetime')
# Out:
#                        DELHI     BRPL    BYPL     NDPL    NDMC    MES   day  \
# datetime
# 2022-01-01 00:00:00  2144.41   860.87  428.55   691.40  117.82  25.93   1.0
# 2022-01-01 01:00:00  1839.04   727.39  349.29   609.45  111.57  23.50   1.0
# 2022-01-01 02:00:00  1682.70   669.86  316.20   573.91   84.25  22.44   1.0
# 2022-01-01 03:00:00  1578.43   627.90  290.02   539.32   79.86  21.11   1.0
# 2022-01-01 04:00:00  1584.39   644.04  289.28   542.23   71.18  22.41   1.0
# ...                      ...      ...     ...      ...     ...    ...   ...
# 2022-12-10 07:00:00  2852.01  1199.39  573.20   904.03  120.03  28.24  10.0
# 2022-12-10 08:00:00  3354.54  1402.00  709.99  1045.22  132.66  31.37  10.0
# 2022-12-10 09:00:00  3445.52  1467.49  735.45  1033.79  146.23  29.66  10.0
# 2022-12-10 10:00:00  3775.86  1633.29  773.82  1152.83  151.74  27.70  10.0
# 2022-12-10 11:00:00  3725.10  1574.18  794.12  1146.95  149.58  25.05  10.0
#
#                      month    year  dayofweek
# ...

# %%
past_load['DELHI'].plot(figsize=(5,8))
# Out:
# <Axes: >

# %%
past_load[(past_load['month'] == 1.0) & (past_load['day'] == 3.0)]
# Out:
#       DELHI    BRPL    BYPL    NDPL   NDMC    MES            datetime  day  \
# 24  1907.22  824.90  399.36  569.52  73.38  24.73 2022-01-02 00:00:00  2.0
# 25  1625.36  690.43  330.85  490.32  76.02  22.28 2022-01-02 01:00:00  2.0
# 26  1498.48  631.31  298.05  459.55  74.75  20.80 2022-01-02 02:00:00  2.0
# 27  1444.04  610.19  283.75  442.45  73.51  20.63 2022-01-02 03:00:00  2.0
#
#     month    year  dayofweek  is_weekend  hour
# 24    1.0  2022.0        6.0         1.0   0.0
# 25    1.0  2022.0        6.0         1.0   1.0
# 26    1.0  2022.0        6.0         1.0   2.0
# 27    1.0  2022.0        6.0         1.0   3.0

# %%
past_load.iloc[:20,:]
# Out:
#       DELHI     BRPL    BYPL     NDPL    NDMC    MES            datetime  day  \
# 0   2144.41   860.87  428.55   691.40  117.82  25.93 2022-01-01 00:00:00  1.0
# 1   1839.04   727.39  349.29   609.45  111.57  23.50 2022-01-01 01:00:00  1.0
# 2   1682.70   669.86  316.20   573.91   84.25  22.44 2022-01-01 02:00:00  1.0
# 3   1578.43   627.90  290.02   539.32   79.86  21.11 2022-01-01 03:00:00  1.0
# 4   1584.39   644.04  289.28   542.23   71.18  22.41 2022-01-01 04:00:00  1.0
# 5   1753.52   729.52  320.43   589.47   73.48  24.35 2022-01-01 05:00:00  1.0
# 6   2200.73   915.56  424.79   715.59   90.34  30.11 2022-01-01 06:00:00  1.0
# 7   2969.89  1228.29  627.87   926.01  122.70  37.89 2022-01-01 07:00:00  1.0
# 8   3754.84  1570.12  819.50  1188.76  102.39  41.24 2022-01-01 08:00:00  1.0
# 9   4015.01  1716.47  876.33  1229.77  111.64  41.94 2022-01-01 09:00:00  1.0
# 10  4471.55  1916.57  971.64  1341.66  157.13  42.16 2022-01-01 10:00:00  1.0
# ...

# %%
weather
# Out:
#            datetime (UTC)   coordinates (lat,lon)  temperature (degC)  \
# 0     2022-01-01 00:00:00  (28.557124, 77.083366)                6.51
# 1     2022-01-01 01:00:00  (28.557124, 77.083366)                6.40
# 2     2022-01-01 02:00:00  (28.557124, 77.083366)                6.64
# 3     2022-01-01 03:00:00  (28.557124, 77.083366)                7.03
# 4     2022-01-01 04:00:00  (28.557124, 77.083366)                8.47
# ...                   ...                     ...                 ...
# 8755  2022-12-31 19:00:00  (28.557124, 77.083366)                9.92
# 8756  2022-12-31 20:00:00  (28.557124, 77.083366)                8.96
# 8757  2022-12-31 21:00:00  (28.557124, 77.083366)                9.03
# 8758  2022-12-31 22:00:00  (28.557124, 77.083366)                8.59
# 8759  2022-12-31 23:00:00  (28.557124, 77.083366)                8.76
#
#       relative_humidity (0-1)  total_precipitation (mm of water equivalent)
# ...

# %%
ployying=weather.drop('coordinates (lat,lon)')
