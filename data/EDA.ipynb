# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
past_load=pd.read_csv("raw/past_load/year_2022.csv")
weather=pd.read_csv("raw/weather/weatherdelhi.csv")
holiday=pd.read_csv("raw/holiday/holidays_2022.csv")

# %%
past_load
# Out:
#             DATE  TIMESLOT    DELHI     BRPL    BYPL     NDPL    NDMC    MES
# 0     01-01-2022  00:00:00  2144.41   860.87  428.55   691.40  117.82  25.93
# 1     01-01-2022  01:00:00  1839.04   727.39  349.29   609.45  111.57  23.50
# 2     01-01-2022  02:00:00  1682.70   669.86  316.20   573.91   84.25  22.44
# 3     01-01-2022  03:00:00  1578.43   627.90  290.02   539.32   79.86  21.11
# 4     01-01-2022  04:00:00  1584.39   644.04  289.28   542.23   71.18  22.41
# ...          ...       ...      ...      ...     ...      ...     ...    ...
# 7744  10-12-2022  07:00:00  2852.01  1199.39  573.20   904.03  120.03  28.24
# 7745  10-12-2022  08:00:00  3354.54  1402.00  709.99  1045.22  132.66  31.37
# 7746  10-12-2022  09:00:00  3445.52  1467.49  735.45  1033.79  146.23  29.66
# 7747  10-12-2022  10:00:00  3775.86  1633.29  773.82  1152.83  151.74  27.70
# 7748  10-12-2022  11:00:00  3725.10  1574.18  794.12  1146.95  149.58  25.05
#
# [7749 rows x 8 columns]

# %%
past_load['datetime']=pd.to_datetime(past_load['DATE']+' '+past_load['TIMESLOT'],dayfirst=True)

past_load.drop(['DATE','TIMESLOT'],axis=1,inplace=True)

# %%
past_load.to_csv("raw/past_load/past_load.csv")

# %%
past_load_new=past_load

# %%
holiday.to_csv("raw/holiday/holidays_2022.csv")

# %%
holiday
# Out:
#           Date        Day                                            Holiday  \
# 0   2022-01-01   Saturday                                     New Year's Day
# 1   2022-01-13   Thursday                                              Lohri
# 2   2022-01-14     Friday                 Makara Sankranti/Magha Bihu/Pongal
# 3   2022-01-26  Wednesday                                       Republic Day
# 4   2022-02-05   Saturday                                    Basant Panchami
# 5   2022-03-01    Tuesday                                    Maha Sivarathri
# 6   2022-03-17   Thursday                                       Holika Dahan
# 7   2022-03-18     Friday                                               Holi
# 8   2022-04-02   Saturday                        Chaitra Sukladi/Gudi Padava
# 9   2022-04-10     Sunday                                         Ram Navami
# 10  2022-04-14   Thursday  Dr.B.R.Ambedkar's Birthday/Mahaveer Jayanthi/V...
# ...

# %%
past_load_new['day'] = past_load_new['datetime'].dt.day.astype(float)
past_load_new['month'] = past_load_new['datetime'].dt.month.astype(float)
past_load_new['year'] = past_load_new['datetime'].dt.year.astype(float)
past_load_new['dayofweek'] = past_load_new['datetime'].dt.dayofweek.astype(float)

# %%
past_load
# Out:
#         DELHI     BRPL    BYPL     NDPL    NDMC    MES            datetime  \
# 0     2144.41   860.87  428.55   691.40  117.82  25.93 2022-01-01 00:00:00
# 1     1839.04   727.39  349.29   609.45  111.57  23.50 2022-01-01 01:00:00
# 2     1682.70   669.86  316.20   573.91   84.25  22.44 2022-01-01 02:00:00
# 3     1578.43   627.90  290.02   539.32   79.86  21.11 2022-01-01 03:00:00
# 4     1584.39   644.04  289.28   542.23   71.18  22.41 2022-01-01 04:00:00
# ...       ...      ...     ...      ...     ...    ...                 ...
# 7744  2852.01  1199.39  573.20   904.03  120.03  28.24 2022-12-10 07:00:00
# 7745  3354.54  1402.00  709.99  1045.22  132.66  31.37 2022-12-10 08:00:00
# 7746  3445.52  1467.49  735.45  1033.79  146.23  29.66 2022-12-10 09:00:00
# 7747  3775.86  1633.29  773.82  1152.83  151.74  27.70 2022-12-10 10:00:00
# 7748  3725.10  1574.18  794.12  1146.95  149.58  25.05 2022-12-10 11:00:00
#
#        day  month    year  dayofweek  is_weekend
# ...

# %%
past_load['is_weekend'] = past_load_new['datetime'].dt.dayofweek.isin([5, 6]).astype(float)

# %%
past_load.to_csv("raw/past_load/year_2022.csv")
